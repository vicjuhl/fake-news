# %%
import pathlib as pl
import numpy as np
import pandas as pd
import os

# %%
class TrainingData:
    def __init__(self, file_path: pl.Path) -> None:
        """Instantiate TrainingData class object."""
        self.df = self.get_training_data(file_path)
        self.rinse_training_data()
        self.add_labels()

    def get_training_data(self, file_path: pl.Path) -> pd.DataFrame:
        """Import and typecast training data from csv file."""
        df = pd.read_csv(file_path)
        df = df.drop(df.columns[0], axis=1)
        df["type"] = pd.Categorical(df.type)
        return df

    def rinse_training_data(self) -> None:
        """Rinse training data."""
        df = self.df[self.df['type'].notna()]
        self.df = df

    def add_labels(self) -> None:
        """Add custom labels based on 'type' column."""
        labels = {
            "unreliable": "unknown",
            "fake": "fake",
            "clickbait": "unknown",
            "conspiracy": "fake",
            "reliable": "real",
            "bias": "unknown",
            "hate": "unknown",
            "junksci": "fake",
            "political": "unknown",
            "unknown": "unknown"
        }
        def lookup_labels(data) -> pd.Categorical:
            return labels[data["type"]]
        self.df["labels"] = self.df.apply(lookup_labels, axis=1)

# %%
# parent = src/, parent.parent = fake-news/
file_path = pl.Path(os.path.abspath('')).parent.resolve() / "data_files/news_sample.csv"

trn = TrainingData(file_path)
trn.df
# Out:
#         id                  domain        type  \
# 0      141                 awm.com  unreliable
# 1      256       beforeitsnews.com        fake
# 2      700             cnnnext.com  unreliable
# 3      768                 awm.com  unreliable
# 4      791    bipartisanreport.com   clickbait
# ..     ...                     ...         ...
# 239  38572       beforeitsnews.com        fake
# 243  39134       beforeitsnews.com        fake
# 244  39208  washingtonexaminer.com   political
# 245  39259       beforeitsnews.com        fake
# 246  39468       beforeitsnews.com        fake
#
#                                                    url  \
# 0    http://awm.com/church-congregation-brings-gift...
# 1    http://beforeitsnews.com/awakening-start-here/...
# 2    http://www.cnnnext.com/video/18526/never-hike-...
# 3    http://awm.com/elusive-alien-of-the-sea-caught...
# 4    http://bipartisanreport.com/2018/01/21/trumps-...
# ..                                                 ...
# 239  http://beforeitsnews.com/celebrities/2014/04/t...
# 243  http://beforeitsnews.com/contributor/pages/20/...
# 244  http://www.washingtonexaminer.com/senate-agree...
# 245  http://beforeitsnews.com/economy/2017/12/priso...
# 246  http://beforeitsnews.com/diy/2017/11/4-useful-...
#
#                                                content  \
# 0    Sometimes the power of Christmas will make you...
# 1    AWAKENING OF 12 STRANDS of DNA – “Reconnecting...
# 2    Never Hike Alone: A Friday the 13th Fan Film U...
# 3    When a rare shark was caught, scientists were ...
# 4    Donald Trump has the unnerving ability to abil...
# ..                                                 ...
# 239  The Disturbing Sugar Daddy/Sugar Baby Relation...
# 243  press\n\nBefore It's News ©\n\npeople powered ...
# 244  The Senate voted late Thursday to start work o...
# 245  Prison for Rahm, God’s Work And Many Others\n\...
# 246  4 Useful Items for Your Tiny Home\n\nHeadline:...
#
#                      scraped_at                 inserted_at  \
# 0    2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 1    2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 2    2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 3    2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 4    2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# ..                          ...                         ...
# 239  2018-01-25 20:13:50.426130  2018-02-02 01:19:41.756632
# 243  2018-01-25 20:13:50.426130  2018-02-02 01:19:41.756632
# 244  2018-01-25 20:13:50.426130  2018-02-02 01:19:41.756632
# 245  2018-01-25 20:13:50.426130  2018-02-02 01:19:41.756632
# 246  2018-01-25 20:13:50.426130  2018-02-02 01:19:41.756632
#
#                      updated_at  \
# 0    2018-02-02 01:19:41.756664
# 1    2018-02-02 01:19:41.756664
# 2    2018-02-02 01:19:41.756664
# 3    2018-02-02 01:19:41.756664
# 4    2018-02-02 01:19:41.756664
# ..                          ...
# 239  2018-02-02 01:19:41.756664
# 243  2018-02-02 01:19:41.756664
# 244  2018-02-02 01:19:41.756664
# 245  2018-02-02 01:19:41.756664
# 246  2018-02-02 01:19:41.756664
#
#                                                  title          authors  \
# 0    Church Congregation Brings Gift to Waitresses ...      Ruth Harris
# 1    AWAKENING OF 12 STRANDS of DNA – “Reconnecting...     Zurich Times
# 2    Never Hike Alone - A Friday the 13th Fan Film ...              NaN
# 3    Elusive ‘Alien Of The Sea ‘ Caught By Scientis...  Alexander Smith
# 4    Trump’s Genius Poll Is Complete & The Results ...  Gloria Christie
# ..                                                 ...              ...
# 239  The Disturbing Sugar Daddy/Sugar Baby Relation...              NaN
# 243                 WELS - Through My Bible on Streams              NaN
# 244  Senate agrees to start work on spending bill, ...  Susan Ferrechio
# 245        Prison for Rahm, God’s Work And Many Others              NaN
# 246                  4 Useful Items for Your Tiny Home        Dimitry K
#
#      keywords                                      meta_keywords  \
# 0         NaN                                               ['']
# 1         NaN                                               ['']
# 2         NaN                                               ['']
# 3         NaN                                               ['']
# 4         NaN                                               ['']
# ..        ...                                                ...
# 239       NaN                                               ['']
# 243       NaN                                               ['']
# 244       NaN  ['Spending', 'Government Shutdown', 'Continuin...
# 245       NaN                                               ['']
# 246       NaN                                               ['']
#
#                                       meta_description tags  summary   labels
# 0                                                  NaN  NaN      NaN  unknown
# 1                                                  NaN  NaN      NaN     fake
# 2    Never Hike Alone: A Friday the 13th Fan Film  ...  NaN      NaN  unknown
# 3                                                  NaN  NaN      NaN  unknown
# 4                                                  NaN  NaN      NaN  unknown
# ..                                                 ...  ...      ...      ...
# 239                                                NaN  NaN      NaN     fake
# 243                                                NaN  NaN      NaN     fake
# 244  'We want to move forward, we want to do someth...  NaN      NaN  unknown
# 245                                                NaN  NaN      NaN     fake
# 246                                                NaN  NaN      NaN     fake
#
# [238 rows x 16 columns]

# %%
# Out:
# 3.710193199082443
# 3.7101931990824424
